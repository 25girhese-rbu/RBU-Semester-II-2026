# %% [markdown]
# # Exp1: To use mathematical software as an advance calculator

# %% [markdown]
# ## Name: Soniya Eknath Girhe.
# ## Section: A7-B3
# ## Roll Number: 59
# ## Date: 21/01/2026.

# %%
585+15
# Out:
# 600

# %%
585-85
# Out:
# 500

# %%
50*50
# Out:
# 2500

# %%
59845/596
# Out:
# 59845/596

# %%
26/13
# Out:
# 2

# %%
5441/8
# Out:
# 5441/8

# %%
1548.0/4
# Out:
# 387.000000000000

# %%
4541/15.0
# Out:
# 302.733333333333

# %%
10/5.n() # .n() is for answer in decimal
# Out:
# 2.00000000000000

# %%
10//4 # // is for Quotient
# Out:
# 2

# %%
13/4.n(digits=7)
# Out:
# 3.250000

# %%
10%4 # % is for Remainder
# Out:
# 2

# %%
2^3
# Out:
# 8

# %%
2**5 # ** gives raise to power by
# Out:
# 32

# %%
A=factorial(10)

# %%
A
# Out:
# 3628800

# %%
A.ndigits() # .ndigits gives number of digits present
# Out:
# 7

# %%
A.digits() # .digits() gives list of all digits of A
# Out:
# [0, 0, 8, 8, 2, 6, 3]

# %%
C=A.digits()
C
# Out:
# [0, 0, 8, 8, 2, 6, 3]

# %%
C[1]
# Out:
# 0

# %%
C[3]
# Out:
# 8

# %%
13.is_prime()
# Out:
# True

# %%
12.is_prime()
# Out:
# False

# %%
12.next_prime()
# Out:
# 13

# %%
121.next_prime()
# Out:
# 127

# %%
list(primes(1,28))
# Out:
# [2, 3, 5, 7, 11, 13, 17, 19, 23]

# %%
exp(0)
# Out:
# 1

# %%
exp(oo)
# Out:
# +Infinity

# %%
exp(-infinity)
# Out:
# 0

# %% [markdown]
# ## Defining a Variable

# %%
A=1597865
B=1498959

# %%
A+B
# Out:
# 3096824

# %%
A-B
# Out:
# 98906

# %%
A/B
# Out:
# 1597865/1498959

# %%
A*B
# Out:
# 2395134122535

# %%
A/B.n()
# Out:
# 1.06598312562252

# %%
A.binary()
# Out:
# '110000110000110101001'

# %%
A.divisors()
# Out:
# [1, 5, 313, 1021, 1565, 5105, 319573, 1597865]

# %%
factorial(5)
# Out:
# 120

# %% [markdown]
# ## Defining a Functions

# %%
f(x)=x^2+2*x

# %%
f.derivative()
# Out:
# x |--> 2*x + 2

# %%
show(f.derivative())
# Out:
# x |--> 2*x + 2

# %%
show(f.integral(x))
# Out:
# x |--> 1/3*x^3 + x^2

# %%
integral?
# Out:
# /opt/sagemath-9.3/local/lib/python3.7/site-packages/requests/models.py:847: DeprecationWarning: invalid escape sequence \*
#   """
# /opt/sagemath-9.3/local/lib/python3.7/site-packages/requests/api.py:67: DeprecationWarning: invalid escape sequence \*
#   """
# /opt/sagemath-9.3/local/lib/python3.7/site-packages/requests/api.py:80: DeprecationWarning: invalid escape sequence \*
#   """
# /opt/sagemath-9.3/local/lib/python3.7/site-packages/requests/api.py:93: DeprecationWarning: invalid escape sequence \*
#   """
# /opt/sagemath-9.3/local/lib/python3.7/site-packages/requests/api.py:108: DeprecationWarning: invalid escape sequence \*
#   """
# /opt/sagemath-9.3/local/lib/python3.7/site-packages/requests/api.py:122: DeprecationWarning: invalid escape sequence \*
#   """
# /opt/sagemath-9.3/local/lib/python3.7/site-packages/requests/api.py:136: DeprecationWarning: invalid escape sequence \*
#   """
# /opt/sagemath-9.3/local/lib/python3.7/site-packages/requests/api.py:148: DeprecationWarning: invalid escape sequence \*
#   """
# /opt/sagemath-9.3/local/lib/python3.7/site-packages/requests/sessions.py:498: DeprecationWarning: invalid escape sequence \*
#   """
# /opt/sagemath-9.3/local/lib/python3.7/site-packages/requests/sessions.py:509: DeprecationWarning: invalid escape sequence \*
#   """
# /opt/sagemath-9.3/local/lib/python3.7/site-packages/requests/sessions.py:520: DeprecationWarning: invalid escape sequence \*
#   """
# /opt/sagemath-9.3/local/lib/python3.7/site-packages/requests/sessions.py:533: DeprecationWarning: invalid escape sequence \*
#   """
# /opt/sagemath-9.3/local/lib/python3.7/site-packages/requests/sessions.py:544: DeprecationWarning: invalid escape sequence \*
#   """
# /opt/sagemath-9.3/local/lib/python3.7/site-packages/requests/sessions.py:555: DeprecationWarning: invalid escape sequence \*
#   """
# /opt/sagemath-9.3/local/lib/python3.7/site-packages/requests/sessions.py:565: DeprecationWarning: invalid escape sequence \*
#   """
# /opt/sagemath-9.3/local/lib/python3.7/site-packages/docutils/writers/latex2e/__init__.py:2978: DeprecationWarning: invalid escape sequence \l
#   self.out.append('}] \leavevmode ')

# %%
show(f.integral(x, 1,2))
# Out:
# 16/3

# %%
sin(pi/2)
# Out:
# 1

# %%
cos(pi/2)
# Out:
# 0

# %%
tan(pi/2)
# Out:
# Infinity

# %%
show(asin(1))
# Out:
# 1/2*pi

# %%
show(acos(0))
# Out:
# 1/2*pi

# %%
show(atan(oo)) # Write oo for Infinity
# Out:
# 1/2*pi

# %%
log(10.0)
# Out:
# 2.30258509299405

# %%
log(10, 10)
# Out:
# 1

# %%
gcd(10, 15)
# Out:
# 5

# %%
lcm(10, 15)
# Out:
# 30

# %% [markdown]
# ## Definig the Formula
# ### Find the Area of Triangle whose sides are 3, 4, 5 by definig a formula

# %%
def Heron(a, b, c):
    s=(a+b+c)/2.0
    Area=sqrt(s*(s-a)*(s-b)*(s-c))
    return(Area)

# %%
Heron(3, 4, 5)
# Out:
# 6.00000000000000

# %%
Heron(13, 14, 15)
# Out:
# 84.0000000000000

# %% [markdown]
# ### Find the Sum of first 10 Natural Number

# %%
def SumN(n):
    N=n*(n+1)/2.0
    return(N)

# %%
SumN(10)
# Out:
# 55.0000000000000

# %%
SumN(50)
# Out:
# 1275.00000000000

# %%
SumN(15)
# Out:
# 120.000000000000

# %% [markdown]
# ### Find the Sum of first 10 Natural Number by using For loop

# %%
k=0
for i in range (1,10):
    k=k+i
k
## in python 10 will exclude therfor put 11 instede 10
# Out:
# 45

# %%
k=0
for i in range (1,11):
    k=k+i
k
# Out:
# 55

# %% [markdown]
# ## Solve Simultaneous Equations $x+y=10 and x-y=2$

# %%
x,y=var('x,y')
show(solve([x+y==10,x-y==2],x,y))
# Out:
# [[x == 6, y == 4]]

# %%
f(x)=x^2-6*x+10

# %%
show(f.roots())
# Out:
# [(-I + 3, 1), (I + 3, 1)]

# %%
f(x)=x^3-2*x^2-5*x+6

# %%
show(f.roots()) # 1 is multiplexicity
# Out:
# [(3, 1), (-2, 1), (1, 1)]

# %% [markdown]
# # Exercise Problem

# %% [markdown]
# ## 1. Find the roots of $x^3 − 2x^2 − 5x + 6 = 0.$

# %%
f(x)=x^3-2*x^2-5*x+6

# %%
show(f.roots())
# Out:
# [(3, 1), (-2, 1), (1, 1)]

# %% [markdown]
# ## 2. Solve the system of non linear equations  $x^2+y^2=4$ and $y=x^2-2$ for $x$ and $y$.

# %%
x,y=var('x,y')
show(solve([x^2+y^2==4,y==x^2-2],x,y))
# Out:
# [[x == -sqrt(3), y == 1], [x == sqrt(3), y == 1], [x == 0, y == -2]]

# %% [markdown]
# ## 3. Find the factors of sum of digits of 275!.

# %%
show(factorial(275))
# Out:
# ...

# %% [markdown]
# ## 4. Suppose an investment is made to a bank by an individual. The bank gives an annual interest at the rate 5%. Return is calculated by using compound interest. Create an user defined function to input the investment amount, the number of years for which investment is made, and print the returns.

# %%
def calculate_returns(principal, years):
    rate = 0.05
    growth = 1
    for i in range(years):
        growth = growth * (1 + rate)
    amount = principal * growth
    return amount

# %%
calculate_returns(10000, 5)
# Out:
# 12762.8156250000

# %% [markdown]
# ## 5. Write a code for finding the area of a quadrilateral by defining the formulaes.

# %%
def quadrilateral_area(a, b, c, d):
    # semi-perimeter
    s = (a + b + c + d) / 2
    # formula
    area = sqrt((s - a) * (s - b) * (s - c) * (s - d))
    return area

# %%
show(quadrilateral_area(5, 6, 7, 8))
# Out:
# 4*sqrt(105)

# %%
show(quadrilateral_area(5.0, 6, 7, 8))
# Out:
# 40.9878030638384

# %% [markdown]
# ## 6. Write a formulae to derive the sum of any AP series where initial term, common differences and number of terms is given.

# %%
def ap_sum(a, d, n):
    sum_ap = (n / 2) * (2 * a + (n - 1) * d)
    return sum_ap

# %%
ap_sum(2, 3, 5)
# Out:
# 40

# %% [markdown]
# ## 7. Define a function for finding the mean of a list of numbers.

# %%
def find_mean(numbers):
    # Step 1: calculate total sum
    total = 0
    for num in numbers:
        total = total + num

    # Step 2: count elements manually
    count = 0
    for num in numbers:
        count = count + 1

    # Step 3: mean formula
    mean = total / count
    return mean

# %%
find_mean([10, 20, 30, 40, 50])
# Out:
# 30

# %% [markdown]
# ## 8. Define a function for finding factorial of a number.

# %%
def factorial(n):
    result = 1
    for i in range(1, n + 1):
        result = result * i
    return result

# %%
factorial(5)
# Out:
# 120

# %% [markdown]
# ## 9. Define a function to check whether a given number is prime or not?

# %%
def is_prime(n):
    # Prime numbers are greater than 1
    if n <= 1:
        return False
    
    # Check divisibility from 2 up to n-1
    for i in range(2, n):
        if n % i == 0:   # if divisible
            return False
    return True

# %%
print(is_prime(7))   # True
print(is_prime(10))  # False
# Out:
# True
# False

# %% [markdown]
# ## 10. Define a formulae to find the sum of square of first natural numbers.

# %%
def sum_of_squares(n):
    return (n * (n + 1) * (2 * n + 1)) / 6

# %%
sum_of_squares(5)
# Out:
# 55

# %% [markdown]
# # Learning: SageMath as an Advanced Calculator
# ## The objective of this experiment was to utilize mathematical software to perform complex calculations and automate mathematical formulas. The key learnings include:
# ### In this first lab experiment, I explored how to use SageMath as a powerful computational tool for engineering mathematics. Here is a summary of what I learned:
# Precision and Number Theory: I learned to handle both symbolic and numerical calculations, as well as tools for prime testing, factorials, and finding GCD/LCM.
# Large Data Handling: I practiced analyzing massive integers by counting their digits and using indexing to access specific values within a large number.
# Algebraic Solvers: I discovered how to define variables and solve complex equations and systems of non-linear equations automatically.
# Programming Logic: I learned to create user-defined functions and use loops to automate repetitive mathematical formulas and series calculations.
